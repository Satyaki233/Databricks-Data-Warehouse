-- %%
use catalog tpcds_lakehouse;

-- %%
-- Run once — future queries skip irrelevant files automatically
ALTER TABLE silver.store_sales
CLUSTER BY (ss_sold_date_sk);

ALTER TABLE silver.web_sales
CLUSTER BY (ws_sold_date_sk);

ALTER TABLE silver.catalog_sales
CLUSTER BY (cs_sold_date_sk);
